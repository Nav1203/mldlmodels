# %%
import matplotlib.pyplot as plt
# Descriptive Plots - Boxplot, Density etc.
import seaborn as sns
import pandas as pd
import numpy as np

# %%
bst_data=pd.read_csv("https://raw.githubusercontent.com/ammishra08/MachineLearning/master/Datasets/boston_train.csv")
bst_data
# Out:
#          CRIM    ZN  INDUS    NOX     RM   AGE     DIS  TAX  PTRATIO  MEDV
# 0     2.30040   0.0  19.58  0.605  6.319  96.1  2.1000  403     14.7  23.8
# 1    13.35980   0.0  18.10  0.693  5.887  94.7  1.7821  666     20.2  12.7
# 2     0.12744   0.0   6.91  0.448  6.770   2.9  5.7209  233     17.9  26.6
# 3     0.15876   0.0  10.81  0.413  5.961  17.5  5.2873  305     19.2  21.7
# 4     0.03768  80.0   1.52  0.404  7.274  38.3  7.3090  329     12.6  34.6
# ..        ...   ...    ...    ...    ...   ...     ...  ...      ...   ...
# 395   0.23912   0.0   9.69  0.585  6.019  65.3  2.4091  391     19.2  21.2
# 396   0.04560   0.0  13.89  0.550  5.888  56.0  3.1121  276     16.4  23.3
# 397   1.38799   0.0   8.14  0.538  5.950  82.0  3.9900  307     21.0  13.2
# 398   7.36711   0.0  18.10  0.679  6.193  78.1  1.9356  666     20.2  11.0
# 399   0.14150   0.0   6.91  0.448  6.169   6.6  5.7209  233     17.9  25.3
#
# [400 rows x 10 columns]

# %%
bst_data.notnull().sum()
# Out:
# CRIM       400
# ZN         400
# INDUS      400
# NOX        400
# RM         400
# AGE        400
# DIS        400
# TAX        400
# PTRATIO    400
# MEDV       400
# dtype: int64

# %% [markdown]
# **LINE PLOT**
# Use line plot for univariate data analysis (continous)

# %%
plt.figure(figsize=(18,8))
plt.plot(bst_data['AGE'])
plt.title("Age vs Rows Line Plot", fontsize = 10)
plt.xlabel("Row Indexes")
plt.ylabel("AGE")
plt.show()

# %% [markdown]
# **BAR PLOT**
#     Bivariate visualization - X must be discrete and Y can be discrete or continious

# %%
plt.figure(figsize=(18,8))
plt.bar(x=bst_data['ZN'],height = bst_data['AGE'],width=1.5,color='deeppink')
plt.title("Age vs Rows Line Plot", fontsize = 10)
plt.xlabel("Row Indexes")
plt.ylabel("AGE")
plt.show()

# %% [markdown]
# **Histogram**
#     Frequency of data in an interval-variance data
#     Univariate Analysis of Continous

# %%
plt.figure(figsize=(18,8))
plt.hist(bst_data['MEDV'],bins=15,color = 'darkviolet')
plt.title("Histogram", fontsize = 10)
plt.xlabel("MEDV")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# **Scatter Plot**
#     Bivariate Analysis - Relationship Plot between two features

# %%
ir_data=pd.read_csv("https://raw.githubusercontent.com/ammishra08/MachineLearning/master/Datasets/iris.csv")

# %%
ir_data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
ir_data['species'].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
plt.figure(figsize=(13,8))
plt.scatter(x=ir_data['sepal_length'],y=ir_data['petal_length'],c='red')
plt.title('Scatter Plot')
plt.xlabel('Sepal Length')
plt.ylabel('Petal Length')
plt.show()

# %%
plt.style.use('ggplot')
plt.figure(figsize=(13,8))
plt.scatter(x=ir_data['sepal_length'],y=ir_data['petal_length'],c='red', marker='*',label='petal_length')
plt.scatter(x=ir_data['sepal_width'],y=ir_data['petal_width'],c='m',marker='o',label='petal_width')
plt.title('Scatter Plot')
plt.xlabel('Sepal Length/Sepal Width')
plt.ylabel('Petal Length/Petal Width')
plt.legend()
plt.show()

# %% [markdown]
# **Seaborn - Scatterplot**

# %%
sns.set_style("whitegrid")
plt.figure(figsize=(13,8))
sns.scatterplot(x='sepal_length', y='petal_length',data=ir_data, hue ='species',palette='plasma')
plt.show()

# %% [markdown]
# https://matplotlib.org/stable/gallery/color/named_colors.html
# https://matplotlib.org/stable/tutorials/colors/colormaps.html

# %% [markdown]
# **Pie chart**

# %%
ir_data['species'].value_counts()
# Out:
# virginica     50
# setosa        50
# versicolor    50
# Name: species, dtype: int64

# %%
plt.figure(figsize=(8,8))
plt.pie(ir_data['species'].value_counts(), autopct='%0.2f%%',labels = ir_data['species'].unique(),explode=(0,0,0.1))
plt.show()
plt.savefig('piechart.jpg')

# %%
plt.style.use('ggplot')
plt.figure(figsize=(12,8))
sns.distplot(bst_data.MEDV,bins=15)
# Out:
# E:\Ai\projectvenv\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='MEDV', ylabel='Density'>

# %% [markdown]
# **BOXPLOT**

# %%
plt.style.use('ggplot')
plt.figure(figsize=(11,8))
sns.boxplot(data=ir_data, orient='h',palette='plasma')
# Out:
# <AxesSubplot:>

# %% [markdown]
# **CORRELATION**

# %%
# If two variables are linearly varying 
bst_data.corr()
# Out:
#              CRIM        ZN     INDUS       NOX        RM       AGE       DIS  \
# CRIM     1.000000 -0.197764  0.383433  0.407698 -0.219043  0.350003 -0.377643
# ZN      -0.197764  1.000000 -0.532929 -0.521745  0.328418 -0.561062  0.665677
# INDUS    0.383433 -0.532929  1.000000  0.758157 -0.393738  0.644559 -0.717796
# NOX      0.407698 -0.521745  0.758157  1.000000 -0.309519  0.735999 -0.776624
# RM      -0.219043  0.328418 -0.393738 -0.309519  1.000000 -0.253271  0.211441
# AGE      0.350003 -0.561062  0.644559  0.735999 -0.253271  1.000000 -0.742486
# DIS     -0.377643  0.665677 -0.717796 -0.776624  0.211441 -0.742486  1.000000
# TAX      0.563791 -0.323539  0.722435  0.664923 -0.302268  0.521723 -0.555040
# PTRATIO  0.284306 -0.393904  0.386248  0.185284 -0.395436  0.260205 -0.227288
# MEDV    -0.375836  0.365931 -0.465083 -0.410425  0.685041 -0.368922  0.236714
#
#               TAX   PTRATIO      MEDV
# CRIM     0.563791  0.284306 -0.375836
# ...

# %%
plt.figure(figsize=(15,10))
sns.heatmap(bst_data.corr('pearson'),annot=True)
# Out:
# <AxesSubplot:>

# %%
#The threshold value of multicollinearity is +-0.85
